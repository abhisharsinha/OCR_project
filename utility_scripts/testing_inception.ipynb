# %%
from tensorflow.keras.models import Model

# %%
from tensorflow.keras.applications import InceptionResNetV2, ResNet50V2

# %%
resnet = ResNet50V2(weights="imagenet", include_top=False, input_shape=(300,40,3))

# %%
resnet.summary()
# Out:
# Model: "resnet50v2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            [(None, 300, 40, 3)] 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 306, 46, 3)   0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 150, 20, 64)  9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 152, 22, 64)  0           conv1_conv[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 75, 10, 64)   0           pool1_pad[0][0]
# ...

# %%
for layer in resnet.layers:
    layer.trainable = False

# %%
resnet.summary()
# Out:
# Model: "resnet50v2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            [(None, 300, 40, 3)] 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 306, 46, 3)   0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 150, 20, 64)  9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 152, 22, 64)  0           conv1_conv[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 75, 10, 64)   0           pool1_pad[0][0]
# ...

# %%
resnet.layers[-5].name
# Out:
# 'conv5_block3_2_relu'

# %%
resnet.layers[-37].name
# Out:
# 'conv4_block6_out'

# %%
for layer in resnet.layers[-37:-4]:
    layer.trainable = False

# %%
resnet.summary()
# Out:
# Model: "resnet50v2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            [(None, 300, 40, 3)] 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 306, 46, 3)   0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 150, 20, 64)  9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 152, 22, 64)  0           conv1_conv[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 75, 10, 64)   0           pool1_pad[0][0]
# ...
